# %% [markdown]
# # End-to-End Stock Trading Workflow\n\nThis notebook demonstrates data ingestion, feature engineering, model training, backtesting, and daily stock selection.

# %%
import os\nimport sys\nfrom pathlib import Path\n\nPROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nif str(PROJECT_ROOT) not in sys.path:\n    sys.path.insert(0, str(PROJECT_ROOT))

# %%
from stock_trader.config import PipelineConfig\nfrom stock_trader.pipeline import run_end_to_end

# %%
config = PipelineConfig(\n    tickers=['AAPL','MSFT','NVDA','AMZN','GOOGL','META','TSLA'],\n    start='2019-01-01',\n    end='2026-01-01',\n    top_k=3,\n)

# %%
results = run_end_to_end(config)\nresults['metrics']

# %%
results['today_picks']

# %%
ax = results['daily_returns'].set_index('trade_date')['equity_curve'].plot(figsize=(10,4), title='Backtest Equity Curve')\nax.set_ylabel('Equity')
